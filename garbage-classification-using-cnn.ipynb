# %% [markdown]
# # Convolution Neural Network(CNN)
#
# 📌 A convolutional neural network (CNN) is a type of artificial neural network used primarily for image recognition and processing, due to its ability to recognize patterns in images. A CNN is a powerful tool but requires millions of labelled data points for training.

# %% [markdown]
# # Business Problem
#
# 📌 Garbage disposal is a huge problem in today’s world. As the population grows, the waste generated increases and proper treatment and disposal of the generated waste is important to ensure negligible, if not no harm to the environment.
#
# 📌 In this section, we will be classifying the recyclable products into categories based on their materials. This sorting is necessary because each material has its own recycling treatments and procedures.

# %% [markdown]
# # Dataset Story
#
# 📌 The Garbage Classification Dataset contains 6 classifications: cardboard (393), glass (491), metal (400), paper(584), plastic (472) and trash(127).
#
# Example pictures for each category are shown below:
#
# <img src="https://miro.medium.com/max/750/1*qqNAfmUJ986mFWDChGlWQQ.webp" width="500" height="600"/>

# %% [markdown]
# # Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import urllib
import itertools
import random, os, glob
from imutils import paths
from sklearn.utils import shuffle
from urllib.request import urlopen

import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import  ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, SpatialDropout2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img

# %% [markdown]
# # Import Dataset

# %%
dir_path = "/kaggle/input/garbage-classification/"

# %%
target_size = (224, 224)
waste_labels = {"cardboard":0, "glass":1, "metal":2, "paper":3, "plastic":4, "trash":5}

# %%
def load_dataset(path):
  x = []
  labels = []
  image_paths = sorted(list(paths.list_images(path)))
  for image_path in image_paths:
    img = cv2.imread(image_path)
    img = cv2.resize(img, target_size)
    x.append(img)
    label = image_path.split(os.path.sep)[-2]
    labels.append(waste_labels[label])
  x, labels = shuffle(x, labels, random_state=42)
  input_shape = (np.array(x[0]).shape[1], np.array(x[0]).shape[1], 3)
  print("X shape: ", np.array(x).shape)
  print(f"Number of Labels: {len(np.unique(labels))} , Number of Observation: {len(labels)}")
  print("Input Shape: ", input_shape)
  return x, labels, input_shape

# %%
x, labels, input_shape = load_dataset(dir_path)
# Out:
# X shape:  (2527, 224, 224, 3)
#
# Number of Labels: 6 , Number of Observation: 2527
#
# Input Shape:  (224, 224, 3)

# %% [markdown]
# # Visulization Image

# %%
def visualizeation_img(image_batch, labels, num_of_img):
  plt.figure(figsize=(10,10))
  for n in range(num_of_img):
    ax = plt.subplot(5,5,n+1)
    plt.imshow(image_batch[n])
    plt.title(np.array(list(waste_labels.keys()))[to_categorical(labels, num_classes=len(np.unique(labels)))[n] == 1][0].title())
    plt.axis("off")

# %%
visualizeation_img(x, labels, 10)

# %%
def CNN_data_preparation():
  train = ImageDataGenerator(horizontal_flip=True,
                             vertical_flip=True,
                             validation_split=0.1,
                             rescale=1./255,
                             shear_range=0.1,
                             zoom_range=0.1,
                             width_shift_range=0.1,
                             height_shift_range=0.1)
  test = ImageDataGenerator(rescale=1/255, validation_split=0.1)
  train_generator = train.flow_from_directory(directory=dir_path,
                                              target_size=(target_size),
                                              class_mode="categorical",
                                              subset="training")
  test_generator = test.flow_from_directory(directory=dir_path,
                                            target_size=(target_size),
                                            batch_size=251,
                                            class_mode="categorical",
                                            subset="validation")
  return train_generator, test_generator

# %%
train_generator, test_generator = CNN_data_preparation()
# Out:
# Found 2276 images belonging to 6 classes.
#
# Found 251 images belonging to 6 classes.

# %% [markdown]
# # Modeling

# %%
def CNN_create_and_fit_model(train_generator, test_generator, summary=True, fit=True, epochs=100):
  model = Sequential()

  model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", input_shape=(input_shape), activation="relu"))
  model.add(MaxPooling2D(pool_size=2, strides=(2,2)))

  model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=2, strides=(2,2)))

  model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
  model.add(MaxPooling2D(pool_size=2, strides=(2,2)))

  model.add(Flatten())

  model.add(Dense(units=64, activation="relu"))
  model.add(Dropout(rate=0.2))

  model.add(Dense(units=32, activation="relu"))
  model.add(Dropout(rate=0.2))

  model.add(Dense(units=6, activation="softmax"))

  model.compile(loss="categorical_crossentropy",
                optimizer="adam",
                metrics=[tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), "acc"])

  callbacks = [EarlyStopping(monitor="val_loss", patience=50, verbose=1, mode="min"), 
              ModelCheckpoint(filepath="mymodel.h5", monitor="val_loss", mode="min", save_best_only=True, save_weights_only=False, verbose=1)]
  
  if summary:
    model.summary()
  
  if fit:
    history = model.fit_generator(generator=train_generator, epochs=epochs, validation_data=test_generator, 
                                callbacks=callbacks, workers=4, steps_per_epoch=10, validation_steps=251//32) # steps_per_epoch=2276//32, validation_steps=251//32
                                                                                                              # you can choose 2276/32 is 71 per epoch for best accuracy

  return model, history

# %%
model, history = CNN_create_and_fit_model(train_generator, test_generator)
# Out:
# Model: "sequential_2"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  conv2d_5 (Conv2D)           (None, 224, 224, 32)      896
#
#
#
#  max_pooling2d_5 (MaxPooling  (None, 112, 112, 32)     0
#
#  2D)
#
#
#
#  conv2d_6 (Conv2D)           (None, 112, 112, 64)      18496
#
#
#
#  max_pooling2d_6 (MaxPooling  (None, 56, 56, 64)       0
#
#  2D)
#
#
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 32)        18464
#
#
#
#  max_pooling2d_7 (MaxPooling  (None, 28, 28, 32)       0
#
#  2D)
#
#
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#
#
#  dense_6 (Dense)             (None, 64)                1605696
#
#
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#
#
#  dense_7 (Dense)             (None, 32)                2080
#
#
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#
#
#  dense_8 (Dense)             (None, 6)                 198
#
#
#
# =================================================================
#
# Total params: 1,645,830
#
# Trainable params: 1,645,830
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# Epoch 1/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.8125 - precision_2: 0.2308 - recall_2: 0.0094 - acc: 0.1719
#
# Epoch 1: val_loss improved from inf to 1.73777, saving model to mymodel.h5
#
# 10/10 [==============================] - 65s 7s/step - loss: 1.8125 - precision_2: 0.2308 - recall_2: 0.0094 - acc: 0.1719 - val_loss: 1.7378 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_acc: 0.2351
#
# Epoch 2/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.7463 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - acc: 0.2500
#
# Epoch 2: val_loss did not improve from 1.73777
#
# 10/10 [==============================] - 66s 7s/step - loss: 1.7463 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - acc: 0.2500 - val_loss: 1.7484 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00 - val_acc: 0.2351
#
# Epoch 3/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.7423 - precision_2: 0.6667 - recall_2: 0.0068 - acc: 0.2226
#
# Epoch 3: val_loss improved from 1.73777 to 1.67272, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.7423 - precision_2: 0.6667 - recall_2: 0.0068 - acc: 0.2226 - val_loss: 1.6727 - val_precision_2: 1.0000 - val_recall_2: 0.0120 - val_acc: 0.2231
#
# Epoch 4/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.6343 - precision_2: 0.7895 - recall_2: 0.0469 - acc: 0.3094
#
# Epoch 4: val_loss improved from 1.67272 to 1.59813, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.6343 - precision_2: 0.7895 - recall_2: 0.0469 - acc: 0.3094 - val_loss: 1.5981 - val_precision_2: 0.6250 - val_recall_2: 0.0797 - val_acc: 0.3546
#
# Epoch 5/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.6428 - precision_2: 0.5676 - recall_2: 0.0656 - acc: 0.3281
#
# Epoch 5: val_loss did not improve from 1.59813
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.6428 - precision_2: 0.5676 - recall_2: 0.0656 - acc: 0.3281 - val_loss: 1.6168 - val_precision_2: 0.5000 - val_recall_2: 0.0319 - val_acc: 0.3347
#
# Epoch 6/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.7331 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - acc: 0.2313
#
# Epoch 6: val_loss did not improve from 1.59813
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.7331 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - acc: 0.2313 - val_loss: 1.6939 - val_precision_2: 1.0000 - val_recall_2: 0.0120 - val_acc: 0.2351
#
# Epoch 7/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.6369 - precision_2: 0.9474 - recall_2: 0.0562 - acc: 0.2937
#
# Epoch 7: val_loss did not improve from 1.59813
#
# 10/10 [==============================] - 64s 6s/step - loss: 1.6369 - precision_2: 0.9474 - recall_2: 0.0562 - acc: 0.2937 - val_loss: 1.6436 - val_precision_2: 0.5439 - val_recall_2: 0.1235 - val_acc: 0.3068
#
# Epoch 8/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.5924 - precision_2: 0.7174 - recall_2: 0.1031 - acc: 0.3562
#
# Epoch 8: val_loss improved from 1.59813 to 1.54273, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.5924 - precision_2: 0.7174 - recall_2: 0.1031 - acc: 0.3562 - val_loss: 1.5427 - val_precision_2: 0.7234 - val_recall_2: 0.1355 - val_acc: 0.3466
#
# Epoch 9/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.5324 - precision_2: 0.7333 - recall_2: 0.1130 - acc: 0.3836
#
# Epoch 9: val_loss improved from 1.54273 to 1.51963, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.5324 - precision_2: 0.7333 - recall_2: 0.1130 - acc: 0.3836 - val_loss: 1.5196 - val_precision_2: 0.6200 - val_recall_2: 0.1235 - val_acc: 0.3785
#
# Epoch 10/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.7073 - precision_2: 0.5789 - recall_2: 0.0344 - acc: 0.2719
#
# Epoch 10: val_loss did not improve from 1.51963
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.7073 - precision_2: 0.5789 - recall_2: 0.0344 - acc: 0.2719 - val_loss: 1.6585 - val_precision_2: 0.5000 - val_recall_2: 0.0080 - val_acc: 0.2590
#
# Epoch 11/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.6815 - precision_2: 0.5263 - recall_2: 0.0312 - acc: 0.2688
#
# Epoch 11: val_loss did not improve from 1.51963
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.6815 - precision_2: 0.5263 - recall_2: 0.0312 - acc: 0.2688 - val_loss: 1.6655 - val_precision_2: 0.6757 - val_recall_2: 0.0996 - val_acc: 0.3028
#
# Epoch 12/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.6845 - precision_2: 0.5000 - recall_2: 0.0469 - acc: 0.2750
#
# Epoch 12: val_loss did not improve from 1.51963
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.6845 - precision_2: 0.5000 - recall_2: 0.0469 - acc: 0.2750 - val_loss: 1.6030 - val_precision_2: 0.6364 - val_recall_2: 0.0837 - val_acc: 0.3625
#
# Epoch 13/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.5606 - precision_2: 0.8182 - recall_2: 0.1125 - acc: 0.3812
#
# Epoch 13: val_loss improved from 1.51963 to 1.49169, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.5606 - precision_2: 0.8182 - recall_2: 0.1125 - acc: 0.3812 - val_loss: 1.4917 - val_precision_2: 0.8158 - val_recall_2: 0.1235 - val_acc: 0.3705
#
# Epoch 14/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4734 - precision_2: 0.7067 - recall_2: 0.1656 - acc: 0.3594
#
# Epoch 14: val_loss improved from 1.49169 to 1.46719, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.4734 - precision_2: 0.7067 - recall_2: 0.1656 - acc: 0.3594 - val_loss: 1.4672 - val_precision_2: 0.8684 - val_recall_2: 0.1315 - val_acc: 0.3785
#
# Epoch 15/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4511 - precision_2: 0.7931 - recall_2: 0.1437 - acc: 0.3719
#
# Epoch 15: val_loss improved from 1.46719 to 1.42762, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.4511 - precision_2: 0.7931 - recall_2: 0.1437 - acc: 0.3719 - val_loss: 1.4276 - val_precision_2: 0.8036 - val_recall_2: 0.1793 - val_acc: 0.4263
#
# Epoch 16/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4863 - precision_2: 0.7288 - recall_2: 0.1344 - acc: 0.4000
#
# Epoch 16: val_loss did not improve from 1.42762
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.4863 - precision_2: 0.7288 - recall_2: 0.1344 - acc: 0.4000 - val_loss: 1.4388 - val_precision_2: 0.8478 - val_recall_2: 0.1554 - val_acc: 0.3825
#
# Epoch 17/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4777 - precision_2: 0.6615 - recall_2: 0.1344 - acc: 0.3875
#
# Epoch 17: val_loss improved from 1.42762 to 1.42495, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.4777 - precision_2: 0.6615 - recall_2: 0.1344 - acc: 0.3875 - val_loss: 1.4249 - val_precision_2: 0.7955 - val_recall_2: 0.1394 - val_acc: 0.4223
#
# Epoch 18/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3776 - precision_2: 0.8182 - recall_2: 0.1688 - acc: 0.4219
#
# Epoch 18: val_loss did not improve from 1.42495
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3776 - precision_2: 0.8182 - recall_2: 0.1688 - acc: 0.4219 - val_loss: 1.4327 - val_precision_2: 0.6716 - val_recall_2: 0.1793 - val_acc: 0.4462
#
# Epoch 19/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.5209 - precision_2: 0.8627 - recall_2: 0.1375 - acc: 0.3906
#
# Epoch 19: val_loss did not improve from 1.42495
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.5209 - precision_2: 0.8627 - recall_2: 0.1375 - acc: 0.3906 - val_loss: 1.4374 - val_precision_2: 0.6750 - val_recall_2: 0.2151 - val_acc: 0.4024
#
# Epoch 20/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.5127 - precision_2: 0.6481 - recall_2: 0.1199 - acc: 0.3938
#
# Epoch 20: val_loss did not improve from 1.42495
#
# 10/10 [==============================] - 58s 6s/step - loss: 1.5127 - precision_2: 0.6481 - recall_2: 0.1199 - acc: 0.3938 - val_loss: 1.4839 - val_precision_2: 0.8182 - val_recall_2: 0.0717 - val_acc: 0.3984
#
# Epoch 21/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4607 - precision_2: 0.7800 - recall_2: 0.1219 - acc: 0.3844
#
# Epoch 21: val_loss did not improve from 1.42495
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.4607 - precision_2: 0.7800 - recall_2: 0.1219 - acc: 0.3844 - val_loss: 1.4363 - val_precision_2: 0.6825 - val_recall_2: 0.1713 - val_acc: 0.4143
#
# Epoch 22/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4570 - precision_2: 0.6667 - recall_2: 0.1644 - acc: 0.4178
#
# Epoch 22: val_loss improved from 1.42495 to 1.40279, saving model to mymodel.h5
#
# 10/10 [==============================] - 58s 6s/step - loss: 1.4570 - precision_2: 0.6667 - recall_2: 0.1644 - acc: 0.4178 - val_loss: 1.4028 - val_precision_2: 0.7255 - val_recall_2: 0.1474 - val_acc: 0.4582
#
# Epoch 23/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4604 - precision_2: 0.6481 - recall_2: 0.1094 - acc: 0.3594
#
# Epoch 23: val_loss did not improve from 1.40279
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.4604 - precision_2: 0.6481 - recall_2: 0.1094 - acc: 0.3594 - val_loss: 1.4212 - val_precision_2: 0.8182 - val_recall_2: 0.1434 - val_acc: 0.4183
#
# Epoch 24/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4469 - precision_2: 0.7727 - recall_2: 0.1594 - acc: 0.4031
#
# Epoch 24: val_loss improved from 1.40279 to 1.39306, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.4469 - precision_2: 0.7727 - recall_2: 0.1594 - acc: 0.4031 - val_loss: 1.3931 - val_precision_2: 0.7925 - val_recall_2: 0.1673 - val_acc: 0.4183
#
# Epoch 25/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3947 - precision_2: 0.6747 - recall_2: 0.1750 - acc: 0.4313
#
# Epoch 25: val_loss improved from 1.39306 to 1.37565, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.3947 - precision_2: 0.6747 - recall_2: 0.1750 - acc: 0.4313 - val_loss: 1.3757 - val_precision_2: 0.7143 - val_recall_2: 0.2191 - val_acc: 0.4343
#
# Epoch 26/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3883 - precision_2: 0.7083 - recall_2: 0.1594 - acc: 0.4187
#
# Epoch 26: val_loss did not improve from 1.37565
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.3883 - precision_2: 0.7083 - recall_2: 0.1594 - acc: 0.4187 - val_loss: 1.3984 - val_precision_2: 0.8611 - val_recall_2: 0.1235 - val_acc: 0.4582
#
# Epoch 27/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4162 - precision_2: 0.6026 - recall_2: 0.1469 - acc: 0.4125
#
# Epoch 27: val_loss improved from 1.37565 to 1.35919, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.4162 - precision_2: 0.6026 - recall_2: 0.1469 - acc: 0.4125 - val_loss: 1.3592 - val_precision_2: 0.7538 - val_recall_2: 0.1952 - val_acc: 0.4741
#
# Epoch 28/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3824 - precision_2: 0.7586 - recall_2: 0.1375 - acc: 0.4594
#
# Epoch 28: val_loss improved from 1.35919 to 1.33570, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.3824 - precision_2: 0.7586 - recall_2: 0.1375 - acc: 0.4594 - val_loss: 1.3357 - val_precision_2: 0.7931 - val_recall_2: 0.1833 - val_acc: 0.4502
#
# Epoch 29/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3922 - precision_2: 0.6750 - recall_2: 0.1688 - acc: 0.4719
#
# Epoch 29: val_loss improved from 1.33570 to 1.32507, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.3922 - precision_2: 0.6750 - recall_2: 0.1688 - acc: 0.4719 - val_loss: 1.3251 - val_precision_2: 0.8036 - val_recall_2: 0.1793 - val_acc: 0.4741
#
# Epoch 30/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4827 - precision_2: 0.5974 - recall_2: 0.1437 - acc: 0.3688
#
# Epoch 30: val_loss did not improve from 1.32507
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.4827 - precision_2: 0.5974 - recall_2: 0.1437 - acc: 0.3688 - val_loss: 1.3866 - val_precision_2: 0.8511 - val_recall_2: 0.1594 - val_acc: 0.4422
#
# Epoch 31/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4544 - precision_2: 0.7727 - recall_2: 0.1594 - acc: 0.4250
#
# Epoch 31: val_loss did not improve from 1.32507
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.4544 - precision_2: 0.7727 - recall_2: 0.1594 - acc: 0.4250 - val_loss: 1.3680 - val_precision_2: 0.7937 - val_recall_2: 0.1992 - val_acc: 0.4502
#
# Epoch 32/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.4270 - precision_2: 0.7206 - recall_2: 0.1531 - acc: 0.4031
#
# Epoch 32: val_loss did not improve from 1.32507
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.4270 - precision_2: 0.7206 - recall_2: 0.1531 - acc: 0.4031 - val_loss: 1.3672 - val_precision_2: 0.7955 - val_recall_2: 0.1394 - val_acc: 0.4741
#
# Epoch 33/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3762 - precision_2: 0.8493 - recall_2: 0.1937 - acc: 0.3969
#
# Epoch 33: val_loss improved from 1.32507 to 1.31815, saving model to mymodel.h5
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3762 - precision_2: 0.8493 - recall_2: 0.1937 - acc: 0.3969 - val_loss: 1.3182 - val_precision_2: 0.8491 - val_recall_2: 0.1793 - val_acc: 0.4781
#
# Epoch 34/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2830 - precision_2: 0.7685 - recall_2: 0.2594 - acc: 0.4906
#
# Epoch 34: val_loss did not improve from 1.31815
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2830 - precision_2: 0.7685 - recall_2: 0.2594 - acc: 0.4906 - val_loss: 1.3340 - val_precision_2: 0.7297 - val_recall_2: 0.2151 - val_acc: 0.4861
#
# Epoch 35/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2724 - precision_2: 0.7714 - recall_2: 0.2531 - acc: 0.4938
#
# Epoch 35: val_loss improved from 1.31815 to 1.28645, saving model to mymodel.h5
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2724 - precision_2: 0.7714 - recall_2: 0.2531 - acc: 0.4938 - val_loss: 1.2865 - val_precision_2: 0.7215 - val_recall_2: 0.2271 - val_acc: 0.5060
#
# Epoch 36/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3626 - precision_2: 0.6727 - recall_2: 0.2313 - acc: 0.4875
#
# Epoch 36: val_loss did not improve from 1.28645
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3626 - precision_2: 0.6727 - recall_2: 0.2313 - acc: 0.4875 - val_loss: 1.3235 - val_precision_2: 0.7606 - val_recall_2: 0.2151 - val_acc: 0.4661
#
# Epoch 37/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2983 - precision_2: 0.7423 - recall_2: 0.2250 - acc: 0.4844
#
# Epoch 37: val_loss did not improve from 1.28645
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2983 - precision_2: 0.7423 - recall_2: 0.2250 - acc: 0.4844 - val_loss: 1.3215 - val_precision_2: 0.7568 - val_recall_2: 0.2231 - val_acc: 0.5100
#
# Epoch 38/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3166 - precision_2: 0.6900 - recall_2: 0.2156 - acc: 0.4437
#
# Epoch 38: val_loss did not improve from 1.28645
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3166 - precision_2: 0.6900 - recall_2: 0.2156 - acc: 0.4437 - val_loss: 1.3004 - val_precision_2: 0.7397 - val_recall_2: 0.2151 - val_acc: 0.4900
#
# Epoch 39/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3005 - precision_2: 0.7034 - recall_2: 0.2594 - acc: 0.4844
#
# Epoch 39: val_loss did not improve from 1.28645
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3005 - precision_2: 0.7034 - recall_2: 0.2594 - acc: 0.4844 - val_loss: 1.2975 - val_precision_2: 0.6933 - val_recall_2: 0.2072 - val_acc: 0.4940
#
# Epoch 40/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3112 - precision_2: 0.6822 - recall_2: 0.2281 - acc: 0.4375
#
# Epoch 40: val_loss did not improve from 1.28645
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3112 - precision_2: 0.6822 - recall_2: 0.2281 - acc: 0.4375 - val_loss: 1.3246 - val_precision_2: 0.7500 - val_recall_2: 0.2032 - val_acc: 0.4622
#
# Epoch 41/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2587 - precision_2: 0.7545 - recall_2: 0.2594 - acc: 0.5406
#
# Epoch 41: val_loss did not improve from 1.28645
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2587 - precision_2: 0.7545 - recall_2: 0.2594 - acc: 0.5406 - val_loss: 1.3717 - val_precision_2: 0.7037 - val_recall_2: 0.2271 - val_acc: 0.4542
#
# Epoch 42/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3589 - precision_2: 0.6837 - recall_2: 0.2094 - acc: 0.4812
#
# Epoch 42: val_loss did not improve from 1.28645
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.3589 - precision_2: 0.6837 - recall_2: 0.2094 - acc: 0.4812 - val_loss: 1.2927 - val_precision_2: 0.8154 - val_recall_2: 0.2112 - val_acc: 0.5139
#
# Epoch 43/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2404 - precision_2: 0.7481 - recall_2: 0.3063 - acc: 0.5094
#
# Epoch 43: val_loss improved from 1.28645 to 1.27699, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.2404 - precision_2: 0.7481 - recall_2: 0.3063 - acc: 0.5094 - val_loss: 1.2770 - val_precision_2: 0.7468 - val_recall_2: 0.2351 - val_acc: 0.5259
#
# Epoch 44/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3556 - precision_2: 0.6136 - recall_2: 0.2531 - acc: 0.4344
#
# Epoch 44: val_loss did not improve from 1.27699
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3556 - precision_2: 0.6136 - recall_2: 0.2531 - acc: 0.4344 - val_loss: 1.3217 - val_precision_2: 0.7286 - val_recall_2: 0.2032 - val_acc: 0.4781
#
# Epoch 45/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3717 - precision_2: 0.7284 - recall_2: 0.1844 - acc: 0.4375
#
# Epoch 45: val_loss did not improve from 1.27699
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.3717 - precision_2: 0.7284 - recall_2: 0.1844 - acc: 0.4375 - val_loss: 1.3429 - val_precision_2: 0.7727 - val_recall_2: 0.2032 - val_acc: 0.4542
#
# Epoch 46/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3870 - precision_2: 0.6951 - recall_2: 0.1781 - acc: 0.4250
#
# Epoch 46: val_loss did not improve from 1.27699
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.3870 - precision_2: 0.6951 - recall_2: 0.1781 - acc: 0.4250 - val_loss: 1.3052 - val_precision_2: 0.8226 - val_recall_2: 0.2032 - val_acc: 0.4622
#
# Epoch 47/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3493 - precision_2: 0.7381 - recall_2: 0.1937 - acc: 0.4812
#
# Epoch 47: val_loss improved from 1.27699 to 1.26454, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.3493 - precision_2: 0.7381 - recall_2: 0.1937 - acc: 0.4812 - val_loss: 1.2645 - val_precision_2: 0.7093 - val_recall_2: 0.2430 - val_acc: 0.4980
#
# Epoch 48/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1781 - precision_2: 0.7103 - recall_2: 0.3219 - acc: 0.4906
#
# Epoch 48: val_loss did not improve from 1.26454
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.1781 - precision_2: 0.7103 - recall_2: 0.3219 - acc: 0.4906 - val_loss: 1.2676 - val_precision_2: 0.7949 - val_recall_2: 0.2470 - val_acc: 0.5139
#
# Epoch 49/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3422 - precision_2: 0.7172 - recall_2: 0.2219 - acc: 0.4406
#
# Epoch 49: val_loss did not improve from 1.26454
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.3422 - precision_2: 0.7172 - recall_2: 0.2219 - acc: 0.4406 - val_loss: 1.3093 - val_precision_2: 0.7179 - val_recall_2: 0.2231 - val_acc: 0.4462
#
# Epoch 50/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2664 - precision_2: 0.7642 - recall_2: 0.2531 - acc: 0.4781
#
# Epoch 50: val_loss improved from 1.26454 to 1.23114, saving model to mymodel.h5
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2664 - precision_2: 0.7642 - recall_2: 0.2531 - acc: 0.4781 - val_loss: 1.2311 - val_precision_2: 0.7209 - val_recall_2: 0.2470 - val_acc: 0.5179
#
# Epoch 51/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2914 - precision_2: 0.7132 - recall_2: 0.2875 - acc: 0.5188
#
# Epoch 51: val_loss did not improve from 1.23114
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2914 - precision_2: 0.7132 - recall_2: 0.2875 - acc: 0.5188 - val_loss: 1.2313 - val_precision_2: 0.7590 - val_recall_2: 0.2510 - val_acc: 0.5060
#
# Epoch 52/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2871 - precision_2: 0.7172 - recall_2: 0.2219 - acc: 0.4938
#
# Epoch 52: val_loss did not improve from 1.23114
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2871 - precision_2: 0.7172 - recall_2: 0.2219 - acc: 0.4938 - val_loss: 1.2933 - val_precision_2: 0.7536 - val_recall_2: 0.2072 - val_acc: 0.4582
#
# Epoch 53/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3292 - precision_2: 0.7034 - recall_2: 0.2594 - acc: 0.4969
#
# Epoch 53: val_loss improved from 1.23114 to 1.22819, saving model to mymodel.h5
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3292 - precision_2: 0.7034 - recall_2: 0.2594 - acc: 0.4969 - val_loss: 1.2282 - val_precision_2: 0.7586 - val_recall_2: 0.2629 - val_acc: 0.5259
#
# Epoch 54/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2600 - precision_2: 0.7500 - recall_2: 0.2906 - acc: 0.5531
#
# Epoch 54: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2600 - precision_2: 0.7500 - recall_2: 0.2906 - acc: 0.5531 - val_loss: 1.3696 - val_precision_2: 0.5804 - val_recall_2: 0.2590 - val_acc: 0.4622
#
# Epoch 55/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3100 - precision_2: 0.7053 - recall_2: 0.2094 - acc: 0.4812
#
# Epoch 55: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.3100 - precision_2: 0.7053 - recall_2: 0.2094 - acc: 0.4812 - val_loss: 1.2546 - val_precision_2: 0.8615 - val_recall_2: 0.2231 - val_acc: 0.5498
#
# Epoch 56/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2699 - precision_2: 0.7395 - recall_2: 0.2750 - acc: 0.4844
#
# Epoch 56: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 70s 7s/step - loss: 1.2699 - precision_2: 0.7395 - recall_2: 0.2750 - acc: 0.4844 - val_loss: 1.2464 - val_precision_2: 0.7527 - val_recall_2: 0.2789 - val_acc: 0.5339
#
# Epoch 57/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2675 - precision_2: 0.7542 - recall_2: 0.2781 - acc: 0.5000
#
# Epoch 57: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2675 - precision_2: 0.7542 - recall_2: 0.2781 - acc: 0.5000 - val_loss: 1.2932 - val_precision_2: 0.6545 - val_recall_2: 0.2869 - val_acc: 0.4861
#
# Epoch 58/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2327 - precision_2: 0.7652 - recall_2: 0.3156 - acc: 0.4969
#
# Epoch 58: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2327 - precision_2: 0.7652 - recall_2: 0.3156 - acc: 0.4969 - val_loss: 1.2668 - val_precision_2: 0.7391 - val_recall_2: 0.2709 - val_acc: 0.4741
#
# Epoch 59/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3197 - precision_2: 0.7870 - recall_2: 0.2656 - acc: 0.5312
#
# Epoch 59: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3197 - precision_2: 0.7870 - recall_2: 0.2656 - acc: 0.5312 - val_loss: 1.3196 - val_precision_2: 0.7079 - val_recall_2: 0.2510 - val_acc: 0.4422
#
# Epoch 60/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2397 - precision_2: 0.7589 - recall_2: 0.2656 - acc: 0.5219
#
# Epoch 60: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 58s 6s/step - loss: 1.2397 - precision_2: 0.7589 - recall_2: 0.2656 - acc: 0.5219 - val_loss: 1.2733 - val_precision_2: 0.7447 - val_recall_2: 0.2789 - val_acc: 0.5100
#
# Epoch 61/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3054 - precision_2: 0.7561 - recall_2: 0.2906 - acc: 0.5094
#
# Epoch 61: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.3054 - precision_2: 0.7561 - recall_2: 0.2906 - acc: 0.5094 - val_loss: 1.2673 - val_precision_2: 0.7188 - val_recall_2: 0.2749 - val_acc: 0.4821
#
# Epoch 62/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2081 - precision_2: 0.7569 - recall_2: 0.3406 - acc: 0.5156
#
# Epoch 62: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2081 - precision_2: 0.7569 - recall_2: 0.3406 - acc: 0.5156 - val_loss: 1.2315 - val_precision_2: 0.7604 - val_recall_2: 0.2908 - val_acc: 0.5060
#
# Epoch 63/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3228 - precision_2: 0.7350 - recall_2: 0.2688 - acc: 0.4812
#
# Epoch 63: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3228 - precision_2: 0.7350 - recall_2: 0.2688 - acc: 0.4812 - val_loss: 1.2774 - val_precision_2: 0.7500 - val_recall_2: 0.2151 - val_acc: 0.4980
#
# Epoch 64/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2171 - precision_2: 0.7876 - recall_2: 0.2781 - acc: 0.5437
#
# Epoch 64: val_loss did not improve from 1.22819
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.2171 - precision_2: 0.7876 - recall_2: 0.2781 - acc: 0.5437 - val_loss: 1.2712 - val_precision_2: 0.7701 - val_recall_2: 0.2669 - val_acc: 0.4582
#
# Epoch 65/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2444 - precision_2: 0.7544 - recall_2: 0.2688 - acc: 0.4969
#
# Epoch 65: val_loss improved from 1.22819 to 1.18718, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.2444 - precision_2: 0.7544 - recall_2: 0.2688 - acc: 0.4969 - val_loss: 1.1872 - val_precision_2: 0.7753 - val_recall_2: 0.2749 - val_acc: 0.5219
#
# Epoch 66/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1655 - precision_2: 0.8102 - recall_2: 0.3469 - acc: 0.5281
#
# Epoch 66: val_loss improved from 1.18718 to 1.15514, saving model to mymodel.h5
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.1655 - precision_2: 0.8102 - recall_2: 0.3469 - acc: 0.5281 - val_loss: 1.1551 - val_precision_2: 0.7404 - val_recall_2: 0.3068 - val_acc: 0.5458
#
# Epoch 67/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2056 - precision_2: 0.7299 - recall_2: 0.3125 - acc: 0.5250
#
# Epoch 67: val_loss did not improve from 1.15514
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.2056 - precision_2: 0.7299 - recall_2: 0.3125 - acc: 0.5250 - val_loss: 1.2682 - val_precision_2: 0.6970 - val_recall_2: 0.2749 - val_acc: 0.4980
#
# Epoch 68/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2406 - precision_2: 0.7123 - recall_2: 0.3250 - acc: 0.5156
#
# Epoch 68: val_loss did not improve from 1.15514
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.2406 - precision_2: 0.7123 - recall_2: 0.3250 - acc: 0.5156 - val_loss: 1.1707 - val_precision_2: 0.7927 - val_recall_2: 0.2590 - val_acc: 0.5418
#
# Epoch 69/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2185 - precision_2: 0.8241 - recall_2: 0.2781 - acc: 0.5250
#
# Epoch 69: val_loss improved from 1.15514 to 1.15506, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.2185 - precision_2: 0.8241 - recall_2: 0.2781 - acc: 0.5250 - val_loss: 1.1551 - val_precision_2: 0.7841 - val_recall_2: 0.2749 - val_acc: 0.5657
#
# Epoch 70/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1834 - precision_2: 0.7302 - recall_2: 0.3151 - acc: 0.5171
#
# Epoch 70: val_loss did not improve from 1.15506
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.1834 - precision_2: 0.7302 - recall_2: 0.3151 - acc: 0.5171 - val_loss: 1.1714 - val_precision_2: 0.7080 - val_recall_2: 0.3187 - val_acc: 0.5458
#
# Epoch 71/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2626 - precision_2: 0.6753 - recall_2: 0.3250 - acc: 0.5125
#
# Epoch 71: val_loss did not improve from 1.15506
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.2626 - precision_2: 0.6753 - recall_2: 0.3250 - acc: 0.5125 - val_loss: 1.2535 - val_precision_2: 0.7667 - val_recall_2: 0.2749 - val_acc: 0.4861
#
# Epoch 72/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.3391 - precision_2: 0.6667 - recall_2: 0.2329 - acc: 0.4658
#
# Epoch 72: val_loss did not improve from 1.15506
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.3391 - precision_2: 0.6667 - recall_2: 0.2329 - acc: 0.4658 - val_loss: 1.4138 - val_precision_2: 0.6705 - val_recall_2: 0.2351 - val_acc: 0.4303
#
# Epoch 73/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2965 - precision_2: 0.7315 - recall_2: 0.2469 - acc: 0.5031
#
# Epoch 73: val_loss did not improve from 1.15506
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.2965 - precision_2: 0.7315 - recall_2: 0.2469 - acc: 0.5031 - val_loss: 1.2237 - val_precision_2: 0.7922 - val_recall_2: 0.2430 - val_acc: 0.4940
#
# Epoch 74/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2984 - precision_2: 0.7200 - recall_2: 0.2250 - acc: 0.5312
#
# Epoch 74: val_loss improved from 1.15506 to 1.15201, saving model to mymodel.h5
#
# 10/10 [==============================] - 62s 6s/step - loss: 1.2984 - precision_2: 0.7200 - recall_2: 0.2250 - acc: 0.5312 - val_loss: 1.1520 - val_precision_2: 0.8140 - val_recall_2: 0.2789 - val_acc: 0.5418
#
# Epoch 75/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1412 - precision_2: 0.8106 - recall_2: 0.3344 - acc: 0.5531
#
# Epoch 75: val_loss improved from 1.15201 to 1.15066, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.1412 - precision_2: 0.8106 - recall_2: 0.3344 - acc: 0.5531 - val_loss: 1.1507 - val_precision_2: 0.7404 - val_recall_2: 0.3068 - val_acc: 0.5179
#
# Epoch 76/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2517 - precision_2: 0.7051 - recall_2: 0.3438 - acc: 0.5219
#
# Epoch 76: val_loss improved from 1.15066 to 1.11862, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.2517 - precision_2: 0.7051 - recall_2: 0.3438 - acc: 0.5219 - val_loss: 1.1186 - val_precision_2: 0.8118 - val_recall_2: 0.2749 - val_acc: 0.5418
#
# Epoch 77/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1460 - precision_2: 0.8160 - recall_2: 0.3187 - acc: 0.5594
#
# Epoch 77: val_loss did not improve from 1.11862
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.1460 - precision_2: 0.8160 - recall_2: 0.3187 - acc: 0.5594 - val_loss: 1.2066 - val_precision_2: 0.7000 - val_recall_2: 0.2789 - val_acc: 0.4940
#
# Epoch 78/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1440 - precision_2: 0.7108 - recall_2: 0.3688 - acc: 0.5719
#
# Epoch 78: val_loss did not improve from 1.11862
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.1440 - precision_2: 0.7108 - recall_2: 0.3688 - acc: 0.5719 - val_loss: 1.1224 - val_precision_2: 0.8588 - val_recall_2: 0.2908 - val_acc: 0.5458
#
# Epoch 79/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0913 - precision_2: 0.7603 - recall_2: 0.3801 - acc: 0.5822
#
# Epoch 79: val_loss did not improve from 1.11862
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.0913 - precision_2: 0.7603 - recall_2: 0.3801 - acc: 0.5822 - val_loss: 1.1202 - val_precision_2: 0.7619 - val_recall_2: 0.3187 - val_acc: 0.5538
#
# Epoch 80/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0885 - precision_2: 0.7391 - recall_2: 0.3719 - acc: 0.5594
#
# Epoch 80: val_loss did not improve from 1.11862
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.0885 - precision_2: 0.7391 - recall_2: 0.3719 - acc: 0.5594 - val_loss: 1.1479 - val_precision_2: 0.7117 - val_recall_2: 0.3147 - val_acc: 0.5339
#
# Epoch 81/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2505 - precision_2: 0.7161 - recall_2: 0.3469 - acc: 0.5406
#
# Epoch 81: val_loss did not improve from 1.11862
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.2505 - precision_2: 0.7161 - recall_2: 0.3469 - acc: 0.5406 - val_loss: 1.1291 - val_precision_2: 0.8471 - val_recall_2: 0.2869 - val_acc: 0.5618
#
# Epoch 82/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1698 - precision_2: 0.7192 - recall_2: 0.3281 - acc: 0.5813
#
# Epoch 82: val_loss did not improve from 1.11862
#
# 10/10 [==============================] - 62s 6s/step - loss: 1.1698 - precision_2: 0.7192 - recall_2: 0.3281 - acc: 0.5813 - val_loss: 1.3212 - val_precision_2: 0.6607 - val_recall_2: 0.2948 - val_acc: 0.4940
#
# Epoch 83/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1836 - precision_2: 0.6835 - recall_2: 0.2969 - acc: 0.5094
#
# Epoch 83: val_loss did not improve from 1.11862
#
# 10/10 [==============================] - 63s 6s/step - loss: 1.1836 - precision_2: 0.6835 - recall_2: 0.2969 - acc: 0.5094 - val_loss: 1.1253 - val_precision_2: 0.7732 - val_recall_2: 0.2988 - val_acc: 0.5817
#
# Epoch 84/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0972 - precision_2: 0.7405 - recall_2: 0.3656 - acc: 0.5688
#
# Epoch 84: val_loss improved from 1.11862 to 1.09841, saving model to mymodel.h5
#
# 10/10 [==============================] - 62s 6s/step - loss: 1.0972 - precision_2: 0.7405 - recall_2: 0.3656 - acc: 0.5688 - val_loss: 1.0984 - val_precision_2: 0.8235 - val_recall_2: 0.3347 - val_acc: 0.5657
#
# Epoch 85/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1332 - precision_2: 0.7169 - recall_2: 0.3719 - acc: 0.5500
#
# Epoch 85: val_loss did not improve from 1.09841
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.1332 - precision_2: 0.7169 - recall_2: 0.3719 - acc: 0.5500 - val_loss: 1.2041 - val_precision_2: 0.6718 - val_recall_2: 0.3506 - val_acc: 0.5339
#
# Epoch 86/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1870 - precision_2: 0.7353 - recall_2: 0.3425 - acc: 0.5685
#
# Epoch 86: val_loss did not improve from 1.09841
#
# 10/10 [==============================] - 59s 6s/step - loss: 1.1870 - precision_2: 0.7353 - recall_2: 0.3425 - acc: 0.5685 - val_loss: 1.1846 - val_precision_2: 0.7810 - val_recall_2: 0.3267 - val_acc: 0.5219
#
# Epoch 87/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.2111 - precision_2: 0.6918 - recall_2: 0.3156 - acc: 0.5250
#
# Epoch 87: val_loss did not improve from 1.09841
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.2111 - precision_2: 0.6918 - recall_2: 0.3156 - acc: 0.5250 - val_loss: 1.1582 - val_precision_2: 0.6981 - val_recall_2: 0.2948 - val_acc: 0.5339
#
# Epoch 88/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0678 - precision_2: 0.7861 - recall_2: 0.4250 - acc: 0.6062
#
# Epoch 88: val_loss did not improve from 1.09841
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.0678 - precision_2: 0.7861 - recall_2: 0.4250 - acc: 0.6062 - val_loss: 1.1249 - val_precision_2: 0.7379 - val_recall_2: 0.3028 - val_acc: 0.5578
#
# Epoch 89/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0687 - precision_2: 0.7633 - recall_2: 0.4031 - acc: 0.6031
#
# Epoch 89: val_loss improved from 1.09841 to 1.09418, saving model to mymodel.h5
#
# 10/10 [==============================] - 62s 6s/step - loss: 1.0687 - precision_2: 0.7633 - recall_2: 0.4031 - acc: 0.6031 - val_loss: 1.0942 - val_precision_2: 0.7381 - val_recall_2: 0.3705 - val_acc: 0.5697
#
# Epoch 90/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0371 - precision_2: 0.7760 - recall_2: 0.4437 - acc: 0.6156
#
# Epoch 90: val_loss improved from 1.09418 to 1.08356, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.0371 - precision_2: 0.7760 - recall_2: 0.4437 - acc: 0.6156 - val_loss: 1.0836 - val_precision_2: 0.7538 - val_recall_2: 0.3904 - val_acc: 0.5737
#
# Epoch 91/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0434 - precision_2: 0.7435 - recall_2: 0.4437 - acc: 0.6156
#
# Epoch 91: val_loss did not improve from 1.08356
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.0434 - precision_2: 0.7435 - recall_2: 0.4437 - acc: 0.6156 - val_loss: 1.0969 - val_precision_2: 0.7333 - val_recall_2: 0.3944 - val_acc: 0.5618
#
# Epoch 92/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0885 - precision_2: 0.7640 - recall_2: 0.4250 - acc: 0.5969
#
# Epoch 92: val_loss improved from 1.08356 to 1.07462, saving model to mymodel.h5
#
# 10/10 [==============================] - 62s 6s/step - loss: 1.0885 - precision_2: 0.7640 - recall_2: 0.4250 - acc: 0.5969 - val_loss: 1.0746 - val_precision_2: 0.8400 - val_recall_2: 0.3347 - val_acc: 0.5857
#
# Epoch 93/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0430 - precision_2: 0.8086 - recall_2: 0.4094 - acc: 0.5969
#
# Epoch 93: val_loss did not improve from 1.07462
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.0430 - precision_2: 0.8086 - recall_2: 0.4094 - acc: 0.5969 - val_loss: 1.1745 - val_precision_2: 0.7521 - val_recall_2: 0.3625 - val_acc: 0.5538
#
# Epoch 94/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0833 - precision_2: 0.7396 - recall_2: 0.3906 - acc: 0.5813
#
# Epoch 94: val_loss did not improve from 1.07462
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.0833 - precision_2: 0.7396 - recall_2: 0.3906 - acc: 0.5813 - val_loss: 1.1637 - val_precision_2: 0.7482 - val_recall_2: 0.4143 - val_acc: 0.5618
#
# Epoch 95/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1229 - precision_2: 0.7097 - recall_2: 0.4125 - acc: 0.5875
#
# Epoch 95: val_loss did not improve from 1.07462
#
# 10/10 [==============================] - 63s 6s/step - loss: 1.1229 - precision_2: 0.7097 - recall_2: 0.4125 - acc: 0.5875 - val_loss: 1.1915 - val_precision_2: 0.7015 - val_recall_2: 0.3745 - val_acc: 0.5458
#
# Epoch 96/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1038 - precision_2: 0.7126 - recall_2: 0.3719 - acc: 0.5656
#
# Epoch 96: val_loss improved from 1.07462 to 1.06379, saving model to mymodel.h5
#
# 10/10 [==============================] - 61s 6s/step - loss: 1.1038 - precision_2: 0.7126 - recall_2: 0.3719 - acc: 0.5656 - val_loss: 1.0638 - val_precision_2: 0.7910 - val_recall_2: 0.4223 - val_acc: 0.5777
#
# Epoch 97/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1418 - precision_2: 0.7418 - recall_2: 0.4219 - acc: 0.5969
#
# Epoch 97: val_loss did not improve from 1.06379
#
# 10/10 [==============================] - 62s 6s/step - loss: 1.1418 - precision_2: 0.7418 - recall_2: 0.4219 - acc: 0.5969 - val_loss: 1.0671 - val_precision_2: 0.7815 - val_recall_2: 0.3705 - val_acc: 0.5896
#
# Epoch 98/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1135 - precision_2: 0.7353 - recall_2: 0.3906 - acc: 0.5813
#
# Epoch 98: val_loss did not improve from 1.06379
#
# 10/10 [==============================] - 62s 6s/step - loss: 1.1135 - precision_2: 0.7353 - recall_2: 0.3906 - acc: 0.5813 - val_loss: 1.0832 - val_precision_2: 0.7903 - val_recall_2: 0.3904 - val_acc: 0.5578
#
# Epoch 99/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.0279 - precision_2: 0.7759 - recall_2: 0.4219 - acc: 0.6156
#
# Epoch 99: val_loss improved from 1.06379 to 1.02052, saving model to mymodel.h5
#
# 10/10 [==============================] - 62s 6s/step - loss: 1.0279 - precision_2: 0.7759 - recall_2: 0.4219 - acc: 0.6156 - val_loss: 1.0205 - val_precision_2: 0.8879 - val_recall_2: 0.4104 - val_acc: 0.6056
#
# Epoch 100/100
#
# 10/10 [==============================] - ETA: 0s - loss: 1.1011 - precision_2: 0.7534 - recall_2: 0.3767 - acc: 0.5753
#
# Epoch 100: val_loss did not improve from 1.02052
#
# 10/10 [==============================] - 60s 6s/step - loss: 1.1011 - precision_2: 0.7534 - recall_2: 0.3767 - acc: 0.5753 - val_loss: 1.0808 - val_precision_2: 0.7851 - val_recall_2: 0.3785 - val_acc: 0.5618

# %% [markdown]
# # Evaluation

# %%
def CNN_model_evaluate(model):
  loss, precision, recall, acc = model.evaluate(test_generator, batch_size=32)
  print("Test Accuracy: %.2f" % (100 * acc))
  print("Test Loss: %.2f" % (100 * loss))
  print("Test Precision: %.2f" % (100 * precision))
  print("Test Recall: %.2f" % (100 * recall))

  X_test, y_test = test_generator.next()
  y_pred = model.predict(X_test)
  y_pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)
  target_names = list(waste_labels.keys())
  print(classification_report(y_test, y_pred, target_names=target_names))

  plt.figure(figsize=(20,5))
  plt.subplot(1,2,1)
  plt.plot(history.history["acc"], color="r", label="Training Accuracy")
  plt.plot(history.history["val_acc"], color="b", label="Validation Accuracy")
  plt.legend(loc="lower right")
  plt.xlabel("Epoch", fontsize=16)
  plt.ylabel("Accuracy", fontsize=16)
  plt.ylim([min(plt.ylim()),1])
  plt.title("Training and Validation Accuracy", fontsize=16)

  plt.subplot(1,2,2)
  plt.plot(history.history["loss"], color="r", label="Training Loss")
  plt.plot(history.history["val_loss"], color="b", label="Validation Loss")
  plt.legend(loc="upper right")
  plt.xlabel("Epoch", fontsize=16)
  plt.ylabel("Loss", fontsize=16)
  plt.ylim([0, max(plt.ylim())])
  plt.title("Training and Validation Loss", fontsize=16)

  return y_test, y_pred

# %%
y_test, y_pred = CNN_model_evaluate(model)
# Out:
# 1/1 [==============================] - 5s 5s/step - loss: 1.0808 - precision_2: 0.7851 - recall_2: 0.3785 - acc: 0.5618
#
# Test Accuracy: 56.18
#
# Test Loss: 108.08
#
# Test Precision: 78.51
#
# Test Recall: 37.85
#
# 8/8 [==============================] - 4s 541ms/step
#
#               precision    recall  f1-score   support
#
#
#
#    cardboard       0.86      0.62      0.72        40
#
#        glass       0.50      0.54      0.52        50
#
#        metal       0.49      0.56      0.52        41
#
#        paper       0.54      0.88      0.67        59
#
#      plastic       0.57      0.17      0.26        48
#
#        trash       0.55      0.46      0.50        13
#
#
#
#     accuracy                           0.56       251
#
#    macro avg       0.58      0.54      0.53       251
#
# weighted avg       0.58      0.56      0.54       251

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
def plot_confusion_matrix(cm, classes, normalize=False, title="Confusion Matrix", cmap=plt.cm.OrRd):
  if normalize:
    cm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
  
  plt.figure(figsize=(8,6))
  plt.imshow(cm, interpolation="nearest", cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)
  fmt = ".2f" if normalize else "d"
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")
  plt.tight_layout()
  plt.ylabel("True Labels", fontweight="bold")
  plt.xlabel("Predicted Labels", fontweight="bold")

# %%
plot_confusion_matrix(cm, waste_labels.keys())

# %% [markdown]
# # Model Testing

# %%
def CNN_model_testing(path):
  img = image.load_img(path, target_size=(target_size))
  img = image.img_to_array(img, dtype=np.uint8)
  img = np.array(img)/255.0
  p = model.predict(img.reshape(1,224,224,3))
  predicted_class = np.argmax(p[0])
  return img, p, predicted_class

# %%
img, p, predicted_class = CNN_model_testing("/content/drive/MyDrive/Colab Notebooks/datasets/Garbage classification/metal/metal100.jpg")
# Out:
# 1/1 [==============================] - 0s 77ms/step

# %%
waste_labels = {0:"cardboard", 1:"glass", 2:"metal", 3:"paper", 4:"plastic", 5:"trash"}
def plot_model_testing(img, p, predicted_class):
  plt.axis("off")
  plt.imshow(img.squeeze())
  plt.title("Maximum Probabilty: " + str(np.max(p[0], axis=-1)) + "\n" + "Predicted Class: " + str(waste_labels[predicted_class]))
  plt.imshow(img);

# %%
plot_model_testing(img, p, predicted_class)
